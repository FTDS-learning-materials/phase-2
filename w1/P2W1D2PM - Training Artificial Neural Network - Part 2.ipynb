# %% [markdown]
# # Phase 2 - Week 1 - Day 2 PM - Training Artificial Neural Network: Part 2

# %% [markdown]
# In this notebook, we will use Fashion MNIST to demonstrate implementation of transfer learning and dropout layer.
#
# Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# *Source : [url](https://github.com/zalandoresearch/fashion-mnist)*

# %% [markdown]
# <img src='https://www.researchgate.net/profile/Saeed-Reza-Kheradpisheh/publication/342801790/figure/fig2/AS:911232181735425@1594266090934/Sample-images-from-Fashion-MNIST-dataset.png'>

# %% [markdown]
# # A. Import Libraries & Data Loading

# %%
# Import libraries

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization

# Check TensorFlow version
print('TensorFlow version : ', tf.__version__)
print('Pandas version : ', pd.__version__)
print('NumPy version : ', np.__version__)
# Out:
# TensorFlow version :  2.18.0
# Pandas version :  2.2.2
# NumPy version :  2.0.2

# %%
# Data loading

## Download the dataset
fashion_mnist = tf.keras.datasets.fashion_mnist

# Data splitting
(X_train_val, y_train_val), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.15, random_state=42)

print('Train Size : ', X_train.shape)
print('Val Size   : ', X_val.shape)
print('Test Size  : ', X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train Size :  (51000, 28, 28)
# Val Size   :  (9000, 28, 28)
# Test Size  :  (10000, 28, 28)

# %%
# Define the class names

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Function to visualize a group of images

def plot_digits(instances, n_data, images_per_row=10):
  n_rows = int(np.ceil(n_data/images_per_row))
  n_cols = images_per_row
  plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
  for row in range(n_rows):
    for col in range(n_cols):
      index = n_cols * row + col
      plt.subplot(n_rows, n_cols, index + 1)
      plt.imshow(instances[index], cmap='gray', interpolation='nearest')
      plt.axis('off')
      plt.title(class_names[y_train[index]], fontsize=12)
      if index == n_data-1:
        break
  plt.subplots_adjust(wspace=0.2, hspace=0.5)
  plt.show()

# %%
# Visualization of the first 50 images

plot_digits(X_train, 30, images_per_row=10)

# %%
# Feature scaling

X_train_scaled = X_train / 255.
X_val_scaled = X_val / 255.
X_test_scaled = X_test / 255.

# %% [markdown]
# # B - Model Building

# %% [markdown]
# ## B.1 - Without Dropout & Transfer Learning

# %% [markdown]
# For first scenario, we will create a simple ANN model.

# %%
# Create an ANN model without Dropout Layer

## Clear session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

## Create a Sequential model
model_1 = Sequential()
model_1.add(Flatten(input_shape=[28, 28]))
model_1.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_1.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_1.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

## Compile
model_1.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_1.summary()

## Train the model
history_model_1 = model_1.fit(X_train_scaled, y_train, epochs=30, validation_data=(X_val_scaled, y_val))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         7,850 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,070 (31.52 KB)
#  Trainable params: 8,070 (31.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6871 - loss: 0.9408 - val_accuracy: 0.8172 - val_loss: 0.5300
# Epoch 2/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8295 - loss: 0.4932 - val_accuracy: 0.8324 - val_loss: 0.4790
# Epoch 3/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8435 - loss: 0.4512 - val_accuracy: 0.8393 - val_loss: 0.4582
# Epoch 4/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8501 - loss: 0.4315 - val_accuracy: 0.8446 - val_loss: 0.4431
# Epoch 5/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8543 - loss: 0.4152 - val_accuracy: 0.8472 - val_loss: 0.4345
# Epoch 6/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8584 - loss: 0.4037 - val_accuracy: 0.8490 - val_loss: 0.4287
# Epoch 7/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8608 - loss: 0.3954 - val_accuracy: 0.8488 - val_loss: 0.4267
# Epoch 8/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8625 - loss: 0.3880 - val_accuracy: 0.8502 - val_loss: 0.4251
# Epoch 9/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8641 - loss: 0.3818 - val_accuracy: 0.8492 - val_loss: 0.4230
# Epoch 10/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8658 - loss: 0.3763 - val_accuracy: 0.8498 - val_loss: 0.4219
# Epoch 11/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8670 - loss: 0.3716 - val_accuracy: 0.8502 - val_loss: 0.4201
# Epoch 12/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8676 - loss: 0.3682 - val_accuracy: 0.8501 - val_loss: 0.4191
# Epoch 13/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8687 - loss: 0.3646 - val_accuracy: 0.8507 - val_loss: 0.4186
# Epoch 14/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8689 - loss: 0.3618 - val_accuracy: 0.8521 - val_loss: 0.4164
# Epoch 15/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8700 - loss: 0.3583 - val_accuracy: 0.8529 - val_loss: 0.4170
# Epoch 16/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8711 - loss: 0.3552 - val_accuracy: 0.8531 - val_loss: 0.4163
# Epoch 17/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8726 - loss: 0.3523 - val_accuracy: 0.8537 - val_loss: 0.4151
# Epoch 18/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8733 - loss: 0.3497 - val_accuracy: 0.8550 - val_loss: 0.4150
# Epoch 19/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8751 - loss: 0.3463 - val_accuracy: 0.8547 - val_loss: 0.4150
# Epoch 20/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8753 - loss: 0.3438 - val_accuracy: 0.8538 - val_loss: 0.4145
# Epoch 21/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8752 - loss: 0.3421 - val_accuracy: 0.8572 - val_loss: 0.4137
# Epoch 22/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8760 - loss: 0.3395 - val_accuracy: 0.8549 - val_loss: 0.4139
# Epoch 23/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8764 - loss: 0.3374 - val_accuracy: 0.8564 - val_loss: 0.4147
# Epoch 24/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8772 - loss: 0.3351 - val_accuracy: 0.8564 - val_loss: 0.4162
# Epoch 25/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8774 - loss: 0.3332 - val_accuracy: 0.8561 - val_loss: 0.4167
# Epoch 26/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8785 - loss: 0.3310 - val_accuracy: 0.8586 - val_loss: 0.4153
# Epoch 27/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8792 - loss: 0.3291 - val_accuracy: 0.8580 - val_loss: 0.4151
# Epoch 28/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8798 - loss: 0.3276 - val_accuracy: 0.8584 - val_loss: 0.4150
# Epoch 29/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8806 - loss: 0.3256 - val_accuracy: 0.8586 - val_loss: 0.4153
# Epoch 30/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8811 - loss: 0.3243 - val_accuracy: 0.8578 - val_loss: 0.4169
# CPU times: user 2min 28s, sys: 11.6 s, total: 2min 39s
# Wall time: 2min 39s

# %%
# Plot training results

history_model_1 = pd.DataFrame(history_model_1.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_1[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_1[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# It can be seen that out model is slightly overfit during the training. To improve this model, in the next scenarios we will add Dropout layer and Transfer Learning.

# %% [markdown]
# ## B.2 - Add Dropout

# %% [markdown]
# For the second scenario, we will add Dropout Layer to reduce overfitting.

# %%
# Create an ANN model with Dropout Layer

## Clear session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

## Create a Sequential model with Dropout Layer
model_2 = Sequential()
model_2.add(Flatten(input_shape=[28, 28]))
model_2.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_2.add(Dropout(0.1, seed=seed))
model_2.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_2.add(Dropout(0.1, seed=seed))
model_2.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

## Compile
model_2.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_2.summary()

## Train the model
history_model_2 = model_2.fit(X_train_scaled, y_train, epochs=30, validation_data=(X_val_scaled, y_val))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         7,850 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,070 (31.52 KB)
#  Trainable params: 8,070 (31.52 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5583 - loss: 1.2597 - val_accuracy: 0.7691 - val_loss: 0.6153
# Epoch 2/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7170 - loss: 0.7563 - val_accuracy: 0.7912 - val_loss: 0.5543
# Epoch 3/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7514 - loss: 0.6695 - val_accuracy: 0.7961 - val_loss: 0.5241
# Epoch 4/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7700 - loss: 0.6270 - val_accuracy: 0.8161 - val_loss: 0.4926
# Epoch 5/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7834 - loss: 0.5970 - val_accuracy: 0.8236 - val_loss: 0.4749
# Epoch 6/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7920 - loss: 0.5876 - val_accuracy: 0.8284 - val_loss: 0.4727
# Epoch 7/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7920 - loss: 0.5734 - val_accuracy: 0.8274 - val_loss: 0.4668
# Epoch 8/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8017 - loss: 0.5593 - val_accuracy: 0.8307 - val_loss: 0.4572
# Epoch 9/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8000 - loss: 0.5541 - val_accuracy: 0.8298 - val_loss: 0.4622
# Epoch 10/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8046 - loss: 0.5426 - val_accuracy: 0.8333 - val_loss: 0.4530
# Epoch 11/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8011 - loss: 0.5433 - val_accuracy: 0.8303 - val_loss: 0.4643
# Epoch 12/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8089 - loss: 0.5348 - val_accuracy: 0.8333 - val_loss: 0.4543
# Epoch 13/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8087 - loss: 0.5266 - val_accuracy: 0.8363 - val_loss: 0.4475
# Epoch 14/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8090 - loss: 0.5277 - val_accuracy: 0.8354 - val_loss: 0.4473
# Epoch 15/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8138 - loss: 0.5193 - val_accuracy: 0.8392 - val_loss: 0.4427
# Epoch 16/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8116 - loss: 0.5199 - val_accuracy: 0.8363 - val_loss: 0.4484
# Epoch 17/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8173 - loss: 0.5144 - val_accuracy: 0.8362 - val_loss: 0.4428
# Epoch 18/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8154 - loss: 0.5143 - val_accuracy: 0.8399 - val_loss: 0.4425
# Epoch 19/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8167 - loss: 0.5104 - val_accuracy: 0.8389 - val_loss: 0.4451
# Epoch 20/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8184 - loss: 0.5058 - val_accuracy: 0.8367 - val_loss: 0.4460
# Epoch 21/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8210 - loss: 0.5050 - val_accuracy: 0.8397 - val_loss: 0.4411
# Epoch 22/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8201 - loss: 0.5017 - val_accuracy: 0.8412 - val_loss: 0.4410
# Epoch 23/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8217 - loss: 0.4959 - val_accuracy: 0.8412 - val_loss: 0.4402
# Epoch 24/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8247 - loss: 0.4933 - val_accuracy: 0.8377 - val_loss: 0.4511
# Epoch 25/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8212 - loss: 0.4972 - val_accuracy: 0.8390 - val_loss: 0.4484
# Epoch 26/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8228 - loss: 0.4909 - val_accuracy: 0.8427 - val_loss: 0.4393
# Epoch 27/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8211 - loss: 0.4965 - val_accuracy: 0.8420 - val_loss: 0.4396
# Epoch 28/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8257 - loss: 0.4843 - val_accuracy: 0.8397 - val_loss: 0.4449
# Epoch 29/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8253 - loss: 0.4863 - val_accuracy: 0.8424 - val_loss: 0.4419
# Epoch 30/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8266 - loss: 0.4836 - val_accuracy: 0.8431 - val_loss: 0.4414
# CPU times: user 2min 29s, sys: 12 s, total: 2min 41s
# Wall time: 2min 26s

# %%
# Plot training results

history_model_2 = pd.DataFrame(history_model_2.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_2[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_2[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# Adding Dropout Layer was succesfully reduce the overfitting. Both loss on train-set and val-set decreasing as epochs increasing.

# %% [markdown]
# ## B.3 - Transfer Learning

# %% [markdown]
# For last scenario, we will implement Transfer Learning. Transfer learning is a technique where a model trained on one task or dataset is adapted and fine-tuned for a different but related task or dataset. It leverages knowledge gained from the source task to improve performance on the target task.
#
# We will add `EfficientNet` layers into our model. Please see this [source](https://keras.io/api/applications/) or [source](https://www.tensorflow.org/api_docs/python/tf/keras/applications/) for more details.

# %% [markdown]
# <img src='https://miro.medium.com/v2/resize:fit:1100/format:png/1*gw37manvc-f9xuFXx9_8WA.png'>

# %% [markdown]
# First, we will change our dataset so it can be processed by `EfficientNet`. `EfficientNet` was trained on dataset called [imagenet](https://www.image-net.org/) with millions of images. The requirement of `EfficientNet` is the image should have exactly 3 inputs channels, and width and height should be no smaller than 32.

# %%
# Change the image dimension

## Step 1 : Expand 1 dimensions
X_train_new = np.expand_dims(X_train, -1)
X_val_new = np.expand_dims(X_val, -1)
X_test_new = np.expand_dims(X_test, -1)

## Step 2 : Convert to RGB
X_train_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_train_new))
X_val_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_val_new))
X_test_new = tf.image.grayscale_to_rgb(tf.convert_to_tensor(X_test_new))

## Step 3 : Resize the image
X_train_new = tf.image.resize(X_train_new, (32, 32))
X_val_new = tf.image.resize(X_val_new, (32, 32))
X_test_new = tf.image.resize(X_test_new, (32, 32))

print('Train size - Before : ', X_train_scaled.shape, ' - After : ', X_train_new.shape)
print('Val size   - Before : ', X_val_scaled.shape, '  - After : ', X_val_new.shape)
print('Test size  - Before : ', X_test_scaled.shape, ' - After : ', X_test_new.shape)
# Out:
# Train size - Before :  (51000, 28, 28)  - After :  (51000, 32, 32, 3)
# Val size   - Before :  (9000, 28, 28)   - After :  (9000, 32, 32, 3)
# Test size  - Before :  (10000, 28, 28)  - After :  (10000, 32, 32, 3)

# %%
# Download the EfficientNet model
pretrained_model= tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(32, 32, 3)
)

# Freeze the lower layer
pretrained_model.trainable= False

# Preprocessing
X_train_new = tf.keras.applications.efficientnet.preprocess_input(X_train_new)
X_val_new = tf.keras.applications.efficientnet.preprocess_input(X_val_new)
X_test_new = tf.keras.applications.efficientnet.preprocess_input(X_test_new)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Crate an ANN model with Transfer Learning

## Clear session
# %%time
seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

## Create a Sequential model with EfficientNet
model_3 = Sequential()
model_3.add(pretrained_model)
model_3.add(Flatten())
model_3.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_3.add(Dense(10, activation='relu', kernel_initializer=tf.keras.initializers.HeNormal(seed)))
model_3.add(Dense(10, activation='softmax', kernel_initializer=tf.keras.initializers.GlorotNormal(seed)))

## Compile
model_3.compile(loss='sparse_categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
model_3.summary()

## Train the model
history_model_3 = model_3.fit(X_train_new, y_train, epochs=30, validation_data=(X_val_new, y_val))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 1, 1, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        12,810 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,062,601 (15.50 MB)
#  Trainable params: 13,030 (50.90 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 51s 20ms/step - accuracy: 0.5377 - loss: 1.3115 - val_accuracy: 0.7683 - val_loss: 0.6615
# Epoch 2/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 54s 8ms/step - accuracy: 0.7525 - loss: 0.6912 - val_accuracy: 0.7882 - val_loss: 0.6017
# Epoch 3/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.7767 - loss: 0.6236 - val_accuracy: 0.8073 - val_loss: 0.5465
# Epoch 4/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7911 - loss: 0.5857 - val_accuracy: 0.8097 - val_loss: 0.5395
# Epoch 5/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7969 - loss: 0.5667 - val_accuracy: 0.8166 - val_loss: 0.5166
# Epoch 6/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8021 - loss: 0.5484 - val_accuracy: 0.8172 - val_loss: 0.5171
# Epoch 7/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8026 - loss: 0.5454 - val_accuracy: 0.8218 - val_loss: 0.5004
# Epoch 8/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8095 - loss: 0.5301 - val_accuracy: 0.8226 - val_loss: 0.4950
# Epoch 9/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8139 - loss: 0.5179 - val_accuracy: 0.8258 - val_loss: 0.4873
# Epoch 10/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8149 - loss: 0.5148 - val_accuracy: 0.8221 - val_loss: 0.5008
# Epoch 11/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8144 - loss: 0.5124 - val_accuracy: 0.8274 - val_loss: 0.4877
# Epoch 12/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8168 - loss: 0.5087 - val_accuracy: 0.8282 - val_loss: 0.4874
# Epoch 13/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8165 - loss: 0.5022 - val_accuracy: 0.8284 - val_loss: 0.4847
# Epoch 14/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8187 - loss: 0.4987 - val_accuracy: 0.8314 - val_loss: 0.4735
# Epoch 15/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8212 - loss: 0.4913 - val_accuracy: 0.8288 - val_loss: 0.4875
# Epoch 16/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.8223 - loss: 0.4917 - val_accuracy: 0.8293 - val_loss: 0.4839
# Epoch 17/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.8235 - loss: 0.4895 - val_accuracy: 0.8333 - val_loss: 0.4715
# Epoch 18/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8214 - loss: 0.4874 - val_accuracy: 0.8366 - val_loss: 0.4603
# Epoch 19/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8271 - loss: 0.4768 - val_accuracy: 0.8332 - val_loss: 0.4772
# Epoch 20/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.8258 - loss: 0.4824 - val_accuracy: 0.8370 - val_loss: 0.4686
# Epoch 21/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8286 - loss: 0.4750 - val_accuracy: 0.8321 - val_loss: 0.4691
# Epoch 22/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.8300 - loss: 0.4708 - val_accuracy: 0.8371 - val_loss: 0.4647
# Epoch 23/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.8296 - loss: 0.4701 - val_accuracy: 0.8390 - val_loss: 0.4551
# Epoch 24/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8311 - loss: 0.4663 - val_accuracy: 0.8400 - val_loss: 0.4486
# Epoch 25/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.8285 - loss: 0.4656 - val_accuracy: 0.8414 - val_loss: 0.4502
# Epoch 26/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.8346 - loss: 0.4635 - val_accuracy: 0.8412 - val_loss: 0.4515
# Epoch 27/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.8302 - loss: 0.4638 - val_accuracy: 0.8414 - val_loss: 0.4454
# Epoch 28/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.8316 - loss: 0.4613 - val_accuracy: 0.8424 - val_loss: 0.4454
# Epoch 29/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.8349 - loss: 0.4564 - val_accuracy: 0.8404 - val_loss: 0.4511
# Epoch 30/30
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8353 - loss: 0.4541 - val_accuracy: 0.8424 - val_loss: 0.4469
# CPU times: user 7min 6s, sys: 16.5 s, total: 7min 22s
# Wall time: 9min 22s

# %%
# Plot training results

history_model_3 = pd.DataFrame(history_model_3.history)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.lineplot(data=history_model_3[['accuracy', 'val_accuracy']])
plt.grid()
plt.title('Accuracy vs Val-Accuracy')

plt.subplot(1, 2, 2)
sns.lineplot(data=history_model_3[['loss', 'val_loss']])
plt.grid()
plt.title('Loss vs Val-Loss')
plt.show()

# %% [markdown]
# **INSIGHTS**
#
# 1. It can be seen, our model is considered as good-fit.
#
# 2. Even though, there is no `Dropout` layer or `BatchNormalization` layer, the model can still convergence.
#
# 3. Both losses are still on a downward trend so there is a possibility that if the number of epochs is increased, the model could have higher performance.
